# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# %matplotlib inline
fig,axes = plt.subplots(2,2,figsize=(16,8))

axes[0,0].set_title("DIst of first column")
axes[0,0].hist(df['SepalLengthCm'])

axes[0,1].set_title("DIst of second column")
axes[0,1].hist(df['SepalWidthCm'])

axes[1,0].set_title("DIst of third column")
axes[1,0].hist(df['PetalLengthCm'])

axes[1,1].set_title("DIst of fourth column")
axes[1,1].hist(df['PetalLengthCm'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(x='SepalLengthCm',y='Species',data=df,hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %%
sns.boxplot(x='SepalWidthCm',y='Species',data=df,hue='Species')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Species'>

# %%
sns.boxplot(x='PetalLengthCm',y='Species',data=df,hue='Species')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Species'>

# %%
sns.boxplot(x='PetalWidthCm',y='Species',data=df,hue='Species')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Species'>

# %%
sns.distplot(df['PetalLengthCm'],bins=10,kde=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5192\1440647052.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PetalLengthCm'],bins=10,kde=True)
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>
